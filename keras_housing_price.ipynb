# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.pandas.set_option('display.max_columns',None)
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007547      0.234292      3.409825
# ...

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['price'])

# %%
sns.countplot(df['bedrooms'])

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='price',y='sqft_living',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price',palette='jet')

# %%
df.tail(5)
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 21592      1131     3.0           0     0          3      8        1530
# 21593      5813     2.0           0     0          3      8        2310
# 21594      1350     2.0           0     0          3      7        1020
# 21595      2388     2.0           0     0          3      8        1600
# 21596      1076     2.0           0     0          3      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df['Month'] = pd.to_datetime(df['date'],format='%m/%d/%Y').dt.month

df['year'] = pd.to_datetime(df['date'],format='%m/%d/%Y').dt.year

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.drop(['date','id'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  Month  year
# 0    98178  47.5112 -122.257           1340        5650     10  2014
# 1    98125  47.7210 -122.319           1690        7639     12  2014

# %%
df.groupby('Month').mean()['price'].plot()

# %%
sns.barplot(x='year',y='price',data=df)

# %%
X = df.drop('price',axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape , X_test.shape
# Out:
# ((14469, 20), (7128, 20))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(20,activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(20,activation='relu'))

model.add(Dense(1))

# %%
model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=120,epochs=100)
# Out:
# Train on 14469 samples, validate on 7128 samples
# Epoch 1/100
# 14469/14469 [==============================] - 2s 133us/sample - loss: 430854726703.7711 - val_loss: 418607142560.3232
# Epoch 2/100
# 14469/14469 [==============================] - 1s 45us/sample - loss: 428485535678.1821 - val_loss: 410279556354.5859
# Epoch 3/100
# 14469/14469 [==============================] - 1s 46us/sample - loss: 394749025809.7284 - val_loss: 335453354983.8653
# Epoch 4/100
# 14469/14469 [==============================] - 1s 44us/sample - loss: 256804693902.6233 - val_loss: 154267063306.3434
# Epoch 5/100
# 14469/14469 [==============================] - 1s 45us/sample - loss: 117801116597.4771 - val_loss: 99048952111.4074
# Epoch 6/100
# 14469/14469 [==============================] - 1s 45us/sample - loss: 101194144623.4128 - val_loss: 96950209401.5354
# Epoch 7/100
# 14469/14469 [==============================] - 1s 45us/sample - loss: 98791011206.7676 - val_loss: 94668786567.3266
# Epoch 8/100
# ...

# %%
loss = pd.DataFrame(model.history.history)
loss.plot()

# %%
predict = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,explained_variance_score

print(f'MAE -> {mean_absolute_error(y_test,predict)}')
print(f'MSE -> {mean_squared_error(y_test,predict)}')
print(f'RMSE -> {np.sqrt(mean_squared_error(y_test,predict))}')

print()
print(f'Accuracy -> {r2_score(y_test,predict)}')
# Out:
# MAE -> 112043.48526497615
# MSE -> 32780810385.057957
# RMSE -> 181054.71655015773
#
# Accuracy -> 0.7492618814589762

# %%
explained_variance_score(y_test,predict)
# Out:
# 0.7499270466863684

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test,predict)
plt.plot(y_test,y_test,'r')

# %%
from tensorflow.keras.models import load_model

model.save('House prediction')

m =load_model('House prediction')
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: House prediction\assets

# %%
single = df.drop('price',axis=1).iloc[0]

# %%
single_house = scaler.transform(single.values.reshape(-1,20))

# %%
m.predict(single_house)
# Out:
# array([[301877.53]], dtype=float32)
